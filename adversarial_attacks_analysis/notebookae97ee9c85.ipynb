# %%
# !git clone https://github.com/Pranabgit-hub/VIB_BTP.git
# %cd VIB_BTP
# Out:
# Cloning into 'VIB_BTP'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 208 (delta 50), reused 188 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (208/208), 3.80 MiB | 6.98 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /kaggle/working/VIB_BTP

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# !ls
# Out:
# adversarial_attacks_analysis  requirements.txt	V1  V2	V3

# %%
# !cd adversarial_attacks_analysis

# %%
# !ls
# Out:
# adversarial_attacks_analysis  requirements.txt	V1  V2	V3

# %%
cd adversarial_attacks_analysis
# Out:
# /kaggle/working/VIB_BTP/adversarial_attacks_analysis

# %%
# !ls
# Out:
# adversarial_attacks.py	entropy.py		model.py  run_analysis.py
# divergences.py		information_metrics.py	results

# %%
# !python adversarial_attacks_analysis/run_analysis.py
# Out:
# python3: can't open file '/kaggle/working/VIB_BTP/adversarial_attacks_analysis/adversarial_attacks_analysis/run_analysis.py': [Errno 2] No such file or directory

# %%
cd ..
# Out:
# /kaggle/working/VIB_BTP

# %%
# !python adversarial_attacks_analysis/run_analysis.py
# Out:
# ...
# ADVERSARIAL ATTACKS ANALYSIS
# VIB with KL / Renyi / Tsallis Divergences
# ...
# Device: cuda
# Epochs: 15
# Batch size: 256
# Train subset: 40%
# Test subset: 50%
# Dataset: cifar10
# Architecture: cnn
# Input shape: (3, 32, 32) (flatten=False)
# Num classes: 10
# Beta: 0.001
# Hidden dim: 256
# Latent dim: 64
# Seed: 42
# Renyi alpha: 0.95
# Tsallis alpha: 0.95
# Attack epsilons: [0.02, 0.031, 0.05, 0.08, 0.12]
# PGD steps: 10
# ...
#   8%|██▉                                    | 12.8M/170M [03:08<37:03, 70.9kB/s]^C
#   8%|██▉                                    | 12.8M/170M [03:08<38:38, 68.0kB/s]
# Traceback (most recent call last):
#   File "/kaggle/working/VIB_BTP/adversarial_attacks_analysis/run_analysis.py", line 451, in <module>
#     train_dataset = dataset_cls(
#                     ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/datasets/cifar.py", line 66, in __init__
#     self.download()
# ...

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git clone https://github.com/Pranabgit-hub/VIB_BTP.git
# %cd VIB_BTP
# Out:
# Cloning into 'VIB_BTP'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (174/174), done.:   3% (6/174)
# remote: Total 213 (delta 54), reused 190 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (213/213), 3.81 MiB | 7.53 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /kaggle/working/VIB_BTP/VIB_BTP/VIB_BTP/VIB_BTP/VIB_BTP/VIB_BTP/VIB_BTP/VIB_BTP/VIB_BTP

# %%
# !python adversarial_attacks_analysis/run_analysis.py
# Out:
# ...
# ADVERSARIAL ATTACKS ANALYSIS
# VIB with KL / Renyi / Tsallis Divergences
# ...
# Device: cuda
# Epochs: 15
# Training modes: clean, fgsm, pgd
# Adv-training epsilon: 0.0314 (8/255 default)
# Adv-training PGD steps: 5
# Batch size: 256
# Train subset: 40%
# Test subset: 50%
# Dataset: cifar10
# Architecture: cnn
# Input shape: (3, 32, 32) (flatten=False)
# Num classes: 10
# Beta: 1e-05
# Hidden dim: 256
# Latent dim: 64
# Seed: 42
# Renyi alpha: 0.95
# Tsallis alpha: 0.95
# Attack epsilons: [0.02, 0.031, 0.05, 0.08, 0.12]
# PGD steps: 10
# ...
# 100%|████████████████████████████████████████| 170M/170M [36:17<00:00, 78.3kB/s]
# Subset: using 20000/50000 samples (40%)
# Subset: using 5000/10000 samples (50%)
#
#
# ...
# ADVERSARIAL TRAINING PIPELINE | modes: clean, fgsm, pgd
# ...
#
#
# ############################################################
# TRAINING MODE: CLEAN (results -> results/cifar10/standard/)
# ############################################################
#
#
# ...
# TRAINING KL VIB [CLEAN]
# ...

# %%
# !git clone https://github.com/Pranabgit-hub/VIB_BTP.git
# %cd VIB_BTP
# Out:
# Cloning into 'VIB_BTP'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 213 (delta 54), reused 190 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (213/213), 3.81 MiB | 13.63 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /kaggle/working/VIB_BTP

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git check-ignore -v adversarial_attacks_analysis/results/* 2>/dev/null

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
cd ..
# Out:
# /kaggle/working

# %%
cd VIB_BTP
# Out:
# /kaggle/working/VIB_BTP

# %%
# !ls
# Out:
# adversarial_attacks_analysis  requirements.txt	V1  V2	V3

# %%
import os
print(os.getcwd())
# Out:
# /kaggle/working/VIB_BTP

# %%
# %cd /kaggle/working/VIB_BTP
# Out:
# /kaggle/working/VIB_BTP

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !find /kaggle/working/VIB_BTP -type d -name "results"
# Out:
# /kaggle/working/VIB_BTP/adversarial_attacks_analysis/results
# /kaggle/working/VIB_BTP/V3/results
# /kaggle/working/VIB_BTP/V1/results
# /kaggle/working/VIB_BTP/V2/results

# %%
# %cd /kaggle/working/VIB_BTP
# Out:
# /kaggle/working/VIB_BTP

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
from IPython.display import display, Image
import glob

plots = glob.glob("/kaggle/working/**/*.png", recursive=True)

for plot in plots:
    print(plot)
    display(Image(filename=plot))
# Out:
# UndefVarError: `from` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
